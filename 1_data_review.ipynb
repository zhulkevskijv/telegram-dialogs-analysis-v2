# %% [markdown]
# ## Homework #4. Download and understand a Dataset
# #### Author: `Vladyslav Zhulkevskyi`
# #### Total time spent on h/w (in minutes): ``

# %%
import pandas as pd
import telethon
import seaborn as sns

# %%
sns.set(rc={'figure.figsize':(15.7,8.27)})

# %%
DIALOGS_MERGED_DATA_PATH = "../data/merged_data/dialogs_data_all.csv"
DIALOGS_META_MERGED_DATA_PATH = "../data/merged_data/dialogs_users_all.csv"

# %%
df = pd.read_csv(DIALOGS_MERGED_DATA_PATH)
df_meta = pd.read_csv(DIALOGS_META_MERGED_DATA_PATH)

# %% [markdown]
# ## Task 2.1
# ## Messages data analysis

# %%
df.head(10)
# Out:
#     id                       date                      from_id  \
# 0  879  2021-04-29 09:10:56+00:00  PeerUser(user_id=383618515)
# 1  878  2021-04-29 09:09:44+00:00  PeerUser(user_id=281396127)
# 2  877  2021-04-29 09:09:17+00:00  PeerUser(user_id=281396127)
# 3  876  2021-04-29 09:05:30+00:00  PeerUser(user_id=383618515)
# 4  875  2021-04-29 09:05:24+00:00  PeerUser(user_id=383618515)
# 5  874  2021-04-29 09:05:06+00:00  PeerUser(user_id=383618515)
# 6  873  2021-02-26 10:52:19+00:00  PeerUser(user_id=383618515)
# 7  872  2021-02-26 10:45:56+00:00  PeerUser(user_id=383618515)
# 8  871  2021-02-26 10:45:37+00:00  PeerUser(user_id=383618515)
# 9  870  2021-02-26 09:02:57+00:00   PeerUser(user_id=61792181)
#
#                                 to_id fwd_from  \
# 0  PeerChannel(channel_id=1480379241)      NaN
# 1  PeerChannel(channel_id=1480379241)      NaN
# 2  PeerChannel(channel_id=1480379241)      NaN
# 3  PeerChannel(channel_id=1480379241)      NaN
# ...

# %%
df.shape
# Out:
# (2576905, 9)

# %%
min(df["date"]),max(df["date"])
# Out:
# ('2016-02-01 13:34:12+00:00', '2022-11-01 01:01:34+00:00')

# %%
df.groupby(["type"])["type"].count()
# Out:
# type
# photo       260436
# sticker      47869
# text       2216315
# video        43491
# voice         8794
# Name: type, dtype: int64

# %%
df.groupby(["type"])["duration"].sum()
# Out:
# type
# photo            0.0
# sticker          0.0
# text             0.0
# video      2533484.0
# voice       228398.0
# Name: duration, dtype: float64

# %% [markdown]
# ## Tasks to do:
#
# 1. Define your telegram ID (https://www.alphr.com/telegram-find-user-id/).

# %%
telegram_id = 403299058

# %% [markdown]
# 2. Check on examples that the data you downloaded reflects your telegram messages. Make screenshots (insert your screenshots in this notebook) of 3 different messages in TG and related rows in your dataset here.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2576905 entries, 0 to 2576904
# Data columns (total 9 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   id         int64
#  1   date       object
#  2   from_id    object
#  3   to_id      object
#  4   fwd_from   object
#  5   message    object
#  6   type       object
#  7   duration   float64
#  8   dialog_id  int64
# dtypes: float64(1), int64(2), object(6)
# memory usage: 176.9+ MB

# %%
df["from_id"]
# Out:
# 0          PeerUser(user_id=383618515)
# 1          PeerUser(user_id=281396127)
# 2          PeerUser(user_id=281396127)
# 3          PeerUser(user_id=383618515)
# 4          PeerUser(user_id=383618515)
#                       ...
# 2576900    PeerUser(user_id=403299058)
# 2576901                            NaN
# 2576902    PeerUser(user_id=403299058)
# 2576903    PeerUser(user_id=403299058)
# 2576904                            NaN
# Name: from_id, Length: 2576905, dtype: object

# %%
df.loc[df["from_id"] == f"PeerUser(user_id={telegram_id})"].loc[df["message"] == "ну не запустився мап редюс"]
# Out:
#             id                       date                      from_id  \
# 761475  513938  2022-10-27 19:22:35+00:00  PeerUser(user_id=403299058)
#
#             to_id fwd_from                     message  type  duration  \
# 761475  355148397      NaN  ну не запустився мап редюс  text       NaN
#
#         dialog_id
# 761475  355148397

# %% [markdown]
# ![Screenshot%202022-10-30%20at%2011.58.54.png](attachment:Screenshot%202022-10-30%20at%2011.58.54.png)

# %%
df.loc[df["from_id"] == f"PeerUser(user_id={telegram_id})"].loc[df["message"] == "А ти типу повністю оформився?"]
# Out:
#             id                       date                      from_id  \
# 563548  506699  2022-09-16 08:22:22+00:00  PeerUser(user_id=403299058)
#
#             to_id fwd_from                        message  type  duration  \
# 563548  153272037      NaN  А ти типу повністю оформився?  text       NaN
#
#         dialog_id
# 563548  153272037

# %% [markdown]
# ![Screenshot%202022-10-30%20at%2012.00.50.png](attachment:Screenshot%202022-10-30%20at%2012.00.50.png)

# %%
df.loc[df["from_id"] == f"PeerUser(user_id={telegram_id})"].loc[df["message"] == "за понеділок - четвер в робочий час вимикали на 13-14 годин загалом"]
# Out:
#             id                       date                      from_id  \
# 519753  513953  2022-10-28 07:26:47+00:00  PeerUser(user_id=403299058)
#
#             to_id fwd_from                                            message  \
# 519753  420865092      NaN  за понеділок - четвер в робочий час вимикали н...
#
#         type  duration  dialog_id
# 519753  text       NaN  420865092

# %% [markdown]
# ![Screenshot%202022-10-30%20at%2012.02.20.png](attachment:Screenshot%202022-10-30%20at%2012.02.20.png)

# %% [markdown]
# 3. Find the longest audio message you've ever sent; what's its duration? Make its screenshot (insert your screenshots in this notebook).

# %%
my_messages_df = df.loc[df["from_id"] == f"PeerUser(user_id={telegram_id})"].loc[df["type"] =="voice"]
my_messages_df.loc[my_messages_df['duration'] == my_messages_df['duration'].max()]
# Out:
#              id                       date                      from_id  \
# 2494799  131136  2019-05-13 18:06:31+00:00  PeerUser(user_id=403299058)
#
#                                to_id fwd_from message   type  duration  \
# 2494799  PeerChat(chat_id=284883712)      NaN     NaN  voice    4537.0
#
#          dialog_id
# 2494799 -284883712

# %% [markdown]
# Short comment: I've deleted this message in Telegram, so I can't make a screenshot of this voice message. There is a message where I say why I deleted it. Sorry for Russian

# %% [markdown]
# ![Screenshot%202022-10-30%20at%2016.45.26.png](attachment:Screenshot%202022-10-30%20at%2016.45.26.png)

# %% [markdown]
# 4. Calculate numbers of send and received(s&r) messages.

# %%
df.shape[0]
# Out:
# 2576905

# %%
df.loc[df["from_id"] == f"PeerUser(user_id={telegram_id})"]["from_id"].shape[0]
# Out:
# 179082

# %%
df.loc[df["from_id"] != f"PeerUser(user_id={telegram_id})"].shape[0]
# Out:
# 2397823

# %% [markdown]
# 5. Draw number of send and received(s&r) messages per day (x-axis - is date(from min(date) till max(date)), y-axis number of messages). There should be two lines: blue for received red for send.

# %%
dates_df = df.copy()

# %%
from datetime import datetime

# %%
dates_df['dates'] = df['date'].apply(lambda x: datetime.strptime(x.split(' ')[0], "%Y-%m-%d"))

# %%
dates_df['dates']
# Out:
# 0         2021-04-29
# 1         2021-04-29
# 2         2021-04-29
# 3         2021-04-29
# 4         2021-04-29
#              ...
# 2576900   2018-10-08
# 2576901   2018-10-08
# 2576902   2018-10-08
# 2576903   2018-10-08
# 2576904   2018-10-08
# Name: dates, Length: 2576905, dtype: datetime64[ns]

# %%
sent_df = dates_df.loc[dates_df["from_id"] == f"PeerUser(user_id={telegram_id})"]

# %%
recieved_df = dates_df.loc[dates_df["from_id"] != f"PeerUser(user_id={telegram_id})"]

# %%
sent_df = sent_df[["dates","id"]].groupby(by="dates").count()
recieved_df = recieved_df[["dates","id"]].groupby(by="dates").count()

# %%
sent_df
# Out:
#             id
# dates
# 2017-08-06   1
# 2017-08-08   1
# 2017-08-09   1
# 2017-08-11   1
# 2017-08-22  94
# ...         ..
# 2022-10-27  92
# 2022-10-28  32
# 2022-10-29   5
# 2022-10-30  31
# 2022-10-31  74
#
# [1888 rows x 1 columns]

# %%
sent_df.columns
# Out:
# Index(['id'], dtype='object')

# %%
import matplotlib.pyplot as plt

# %%
ax = sent_df.plot()
recieved_df.plot(ax=ax, figsize=(30,8))
plt.ylabel("Number of messages")
plt.xlabel('Day')
ax.legend(["Sent", "Recieved"])

# %% [markdown]
# 6. Draw a few diagrams to show distributions between post types in the time, a diagram showing the total amount of messages of each type.

# %%
df.groupby(by='type').count().plot(y="id", kind="bar", ylabel=)
# Out:
# <AxesSubplot:xlabel='type'>

# %%
df.groupby(by='type').count().plot(y="id", kind="pie", autopct='%1.0f%%')
# Out:
# <AxesSubplot:ylabel='id'>

# %%
dates_df[["dates","type"]][df["type"]=="photo"].groupby(by="dates").count().plot(figsize=(30,8))
plt.ylabel("Number of messages")
plt.xlabel('Day')
plt.legend(["Photo"])

# %%
dates_df[["dates","type"]][df["type"]=="sticker"].groupby(by="dates").count().plot(figsize=(30,8))
plt.ylabel("Number of messages")
plt.xlabel('Day')
plt.legend(["Sticker"])

# %%
dates_df[["dates","type"]][df["type"]=="voice"].groupby(by="dates").count().plot(figsize=(30,8))
plt.ylabel("Number of messages")
plt.xlabel('Day')
plt.legend(["Voice"])

# %%
dates_df[["dates","type"]][df["type"]=="video"].groupby(by="dates").count().plot(figsize=(30,8))
plt.ylabel("Number of messages")
plt.xlabel('Day')
plt.legend(["Video"])

# %%
dates_df[["dates","type"]][df["type"]=="text"].groupby(by="dates").count().plot(figsize=(30,8))
plt.ylabel("Number of messages")
plt.xlabel('Day')
plt.legend(["Text"])

# %% [markdown]
# 7. Calculate top-10 people to whom you wrote the biggest amount of messages (name, amount of messages).

# %%
my_messages = df.loc[df["from_id"] == f"PeerUser(user_id={telegram_id})"]

# %%
private_dialogs_ids = df_meta[df_meta["type"] == "Private dialog"]["dialog_id"]

# %%
sent_messages_private_dialogs = my_messages[my_messages["dialog_id"].isin(private_dialogs_ids)]
sent_messages_top_10 = sent_messages_private_dialogs[["id","dialog_id"]].groupby(by="dialog_id", as_index=False).count().sort_values("id", ascending=False).head(10)

# %%
import ast

# %%
df_meta_names = df_meta.copy()
df_meta_names["user_id"] = df_meta_names["users"].apply(lambda x: ast.literal_eval(x)["user_id"])
df_meta_names["user_name"] = df_meta_names["users"].apply(lambda x: str(ast.literal_eval(x)["first_name"]))
df_meta_names
# Out:
#            dialog_id                name            type  \
# 0         -280495890  Дозор 32-го созива           Group
# 1         -280495890  Дозор 32-го созива           Group
# 2         -280495890  Дозор 32-го созива           Group
# 3         -280495890  Дозор 32-го созива           Group
# 4         -280495890  Дозор 32-го созива           Group
# ...              ...                 ...             ...
# 11863 -1001647540365  🎓КН Маги 1st level           Group
# 11864      426900495           𝙺𝚒 𝚁𝚎𝚠 🇺🇦  Private dialog
# 11865      209473501    Іван Дмитрасевич  Private dialog
# 11866      556129937   Виктор Михайленко  Private dialog
# 11867       88402632               Artem  Private dialog
#
#                                                    users    user_id  \
# 0      {'user_id': 255026222, 'first_name': 'Kyrylo',...  255026222
# 1      {'user_id': 403299058, 'first_name': 'Vladysla...  403299058
# 2      {'user_id': 365047140, 'first_name': 'Жёнушка'...  365047140
# ...

# %%
sent_messages_top_10["name"] = sent_messages_top_10["dialog_id"].apply(lambda x: df_meta_names[df_meta_names["dialog_id"] == x]["user_name"].iloc[0])

# %%
sent_messages_top_10
# Out:
#      dialog_id     id                     name
# 16   153272037  10910        Здається Влад Bee
# 268  392241081  10723              Соля Адідас
# 85   281396127   8513            Обережно Сімі
# 233  382015004   5562                 Сальпака
# 202  365385817   4929  Та в Шляпці з Майонезом
# 322  425956289   4862                  Мікаель
# 194  362015063   4609        Маленька Чекістка
# 63   249617294   4424            Аня Карлишева
# 101  300865446   3747                  Богдана
# 244  384845835   2760              Міша Федька

# %% [markdown]
# 8. Calculate top-10 people who wrote the biggest amount of messages to you (name, amount of messages).

# %%
recieved_messages = df.loc[df["from_id"] != f"PeerUser(user_id={telegram_id})"]

# %%
recieved_messages_private_dialogs = recieved_messages[recieved_messages["dialog_id"].isin(private_dialogs_ids)]
recieved_messages_top_10 = recieved_messages_private_dialogs[["id","dialog_id"]].groupby(by="dialog_id", as_index=False).count().sort_values("id", ascending=False).head(10)

# %%
recieved_messages_top_10["name"] = recieved_messages_top_10["dialog_id"].apply(lambda x: df_meta_names[df_meta_names["dialog_id"] == x]["user_name"].iloc[0])

# %%
recieved_messages_top_10
# Out:
#       dialog_id     id                     name
# 270   392241081  15935              Соля Адідас
# 87    281396127  11555            Обережно Сімі
# 16    153272037   7441        Здається Влад Bee
# 237   382015004   6258                 Сальпака
# 63    249617294   5743            Аня Карлишева
# 326   425956289   5644                  Мікаель
# 204   365385817   5477  Та в Шляпці з Майонезом
# 103   300865446   5205                  Богдана
# 196   362015063   4644        Маленька Чекістка
# 491  5118514034   4362            ШукаюВіддамUA

# %% [markdown]
# ## Task 2.2
# ## Dialogs data analysis

# %%
df_meta.shape
# Out:
# (11868, 4)

# %%
df_meta.head(10)
# Out:
#        dialog_id                     name            type  \
# 0     -280495890       Дозор 32-го созива           Group
# 1     -280495890       Дозор 32-го созива           Group
# 2     -280495890       Дозор 32-го созива           Group
# 3     -280495890       Дозор 32-го созива           Group
# 4     -280495890       Дозор 32-го созива           Group
# 5     -280495890       Дозор 32-го созива           Group
# 6      506161961          Vladyslav Matus  Private dialog
# 7 -1001695031361  Могилянський Кібер-плац           Group
# 8 -1001695031361  Могилянський Кібер-плац           Group
# 9 -1001695031361  Могилянський Кібер-плац           Group
#
#                                                users
# 0  {'user_id': 255026222, 'first_name': 'Kyrylo',...
# 1  {'user_id': 403299058, 'first_name': 'Vladysla...
# 2  {'user_id': 365047140, 'first_name': 'Жёнушка'...
# 3  {'user_id': 362015063, 'first_name': 'Маленька...
# 4  {'user_id': 281396127, 'first_name': 'Обережно...
# ...

# %%
df_meta.groupby(["type"])["type"].count()
# Out:
# type
# Channel             192
# Group             11167
# Private dialog      509
# Name: type, dtype: int64

# %% [markdown]
# ## Tasks to do:
#
# 1. Find our TG group. Print its id and list of participants.

# %% [markdown]
# 2. Draw distribution of group sizes.

# %%
df_meta
# Out:
#            dialog_id                name            type  \
# 0         -280495890  Дозор 32-го созива           Group
# 1         -280495890  Дозор 32-го созива           Group
# 2         -280495890  Дозор 32-го созива           Group
# 3         -280495890  Дозор 32-го созива           Group
# 4         -280495890  Дозор 32-го созива           Group
# ...              ...                 ...             ...
# 11863 -1001647540365  🎓КН Маги 1st level           Group
# 11864      426900495           𝙺𝚒 𝚁𝚎𝚠 🇺🇦  Private dialog
# 11865      209473501    Іван Дмитрасевич  Private dialog
# 11866      556129937   Виктор Михайленко  Private dialog
# 11867       88402632               Artem  Private dialog
#
#                                                    users
# 0      {'user_id': 255026222, 'first_name': 'Kyrylo',...
# 1      {'user_id': 403299058, 'first_name': 'Vladysla...
# 2      {'user_id': 365047140, 'first_name': 'Жёнушка'...
# ...

# %%
count_group_size = df_meta.loc[df_meta['type'] == "Group"][["dialog_id","name"]].groupby(by="name").count()
count_group_size = count_group_size.rename(columns={'dialog_id': 'Number of users'})
plt.xticks(rotation=65, horizontalalignment='right')
sns.countplot(x=count_group_size["Number of users"])
# Out:
# <AxesSubplot:xlabel='Number of users', ylabel='count'>

# %% [markdown]
# 3. Calculate top-10 the biggest groups/channels.

# %%
df_meta[["dialog_id","name"]].groupby(by="name", as_index=False).count().sort_values(by="dialog_id", ascending=False).head(10)
# Out:
#                                               name  dialog_id
# 696                                     Філіал КМЦ       2594
# 585                        Могилянський Кібер-плац       1386
# 494                       ДОПОМОГА | 📍Хмельницький       1313
# 690                                             ФІ        817
# 645                             Розпізнавання мови        455
# 627  Планета Волонтерів Допомога ЗСУ. Хмельницький        417
# 558                                       Куда це?        156
# 272                        Project management 2020        142
# 666                               Старостат НаУКМА        140
# 20                               Ambassador NaUKMA        135

# %% [markdown]
# 4. Calculate the number of distinct user names you are connected to through any type of dialogue.

# %%
df_meta[["dialog_id","users"]].groupby(by="users").count().shape[0]
# Out:
# 6532
